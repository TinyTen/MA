# %% [markdown]
# # Food Environmental Impact
# ## ILV Datenvisualisierung und Visual Analytics
# ## Christina Köck
# ## Februar 2023
# ### Link to the Gitlab-Repo: https://gitlab.web.fh-kufstein.ac.at/christina.koeck/datenvisualisierung_und_visualanalytics

# %% [markdown]
# Die Visualisierungen werden in diesem Notebook erstellt. Designentscheidungen werden hier dokumentiert. Nach der Entwicklung wird der Code in eine streamlit-Anwendung für das Dashboarding übertragen.
#
# Die Streamlit-Anwendung ist für interessierte Verbaucher mit leicht wissenschaftlichem Hintergrund gedacht. Die Informationen sollten für VerbraucherInnen verständlich sein, allerdings sind gewisse Kenntnisse zu den Nachhaltigkeitsparamtern vorausgesetzt. Besonders die Darstellung der Korrelation setzt Kenntnisse der Pearson-Korrelation voraus. Die Streamlit-Anwendung könnte auch im Unterricht verwendet werden, um Lernenden verschiedene Ernährungsformen näherzubringen. Die Anwendung ist so gestaltet, dass sie mit verschiedenen Fragen durch die Daten führt. Somit soll auf verschiedene Aspekte und Zusammenhänge hingewiesen werden. Die NutzerInnen können dabei selbst wählen, welche Lebenmittel dargestellt werden sollen.

# %% [markdown]
# ### Libraries and data

# %%
# ! pip install cmcrameri

# %%
from cmcrameri import cm
import math as math
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Data are from:
# Hannah Ritchie and Max Roser (2022)
# "Environmental Impacts of Food Production".
# Published online at OurWorldInData.org. 'https://ourworldindata.org/environmental-impacts-of-food' [Online Resource]
# Data was retrieved in a shorter form from https://www.kaggle.com/datasets/selfvivek/environment-impact-of-food-production
df_food = pd.read_excel("Mockdata012.xlsx")
df_food.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df_food.head(3)
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1                 Rice              0.0          0.0   3.6         0.1
# 2             Potatoes              0.0          0.0   0.2         0.0
#
#    Transport  Packging  Retail  Total_emissions  EuEmkg  ...  fat [g]  \
# 0        0.1       0.1     0.1              1.4     NaN  ...     3.50
# 1        0.1       0.1     0.1              4.0   35.07  ...     0.52
# 2        0.1       0.0     0.0              0.3    3.48  ...     0.10
#
#    sat_fat_acids [g]  mon_fat_acids [g]  pol_fat_acids [g]  \
# 0              0.700              0.700              1.900
# 1              0.140              0.161              0.138
# 2              0.026              0.002              0.043
#
#   trans_fat_acids [mg] alcohol [g] ash [g] caffeine [mg] theobromine [mg]  \
# 0                    1           0    1.90             0                0
# ...

# %% [markdown]
# ## Visualisierungen

# %%
def annontations_hor(plots):
    # Place a label for each bar
    for bar in plots.patches:
        # Get X and Y placement of label from rect
        x_value = bar.get_width()
        y_value = bar.get_y() + bar.get_height() / 2

        # Number of points between bar and label; change to your liking
        space = -30
        # Vertical alignment for positive values
        ha = 'left'

        # If value of bar is negative: place label to the left of the bar
        if x_value < 0:
            # Invert space to place label to the left
            space *= -1
            # Horizontally align label to the right
            ha = 'right'

        # Use X value as label and format number
        label = '{:,.0f}'.format(x_value)

        # Create annotation
        plt.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at bar end
            xytext=(space, 0),          # Horizontally shift label by `space`
            textcoords='offset points', # Interpret `xytext` as offset in points
            va='center',                # Vertically center label
            ha=ha,                      # Horizontally align label differently for positive and negative values
            color = 'white',
        fontsize = 25)            # Change label color to white

# %% [markdown]
# ## scientific colormaps (see http://www.fabiocrameri.ch/visualisation.php)

# %%
from colors_cameri import bilbao, tofino, davos, lisbon

# %%
tofino_rgb = [el[1] for el in tofino]

# %%
davos_rgb = [el[1] for el in davos]

# %%
colors =  dict(zip(df_food["Category"].unique(), tofino_rgb))

# %% [markdown]
# ### Verteilungen bestimmter Spalten
#  - alle beliebigen Spalten können gewählt werden werden
#  - Zusammenhänge der Spalten werden dargestellt
#  - ob Parameter positiv oder negative zu bewerten sind, muss User feststellen

# %%
# plt.figure(figsize = (40, 10))
# df_food.plot()
# plt.legend('off')
# # lineplot macht keine Sinn

# %%
df = df_food

# %%
dimensions = ['vitamin_a [IU]', 'saturated_fat [g]', 'protein [g]', 'water [g]']

fig = px.scatter_matrix(df,
    dimensions= dimensions,
    color="Category",
         color_discrete_sequence = davos_rgb
                       )
fig.show()
# Out:
# <div>                            <div id="d26aa52d-389c-46c8-9d26-bd529a585612" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d26aa52d-389c-46c8-9d26-bd529a585612")) {                    Plotly.newPlot(                        "d26aa52d-389c-46c8-9d26-bd529a585612",                        [{"dimensions":[{"axis":{"matches":true},"label":"vitamin_a [IU]","values":[100,0]},{"axis":{"matches":true},"label":"saturated_fat [g]","values":[0.7,0.1]},{"axis":{"matches":true},"label":"protein [g]","values":[0.01,6.5]},{"axis":{"matches":true},"label":"water [g]","values":[36.9,13.29]}],"hovertemplate":"Category=Grains<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"Grains","marker":{"color":"rgb(44, 26, 76)","symbol":"
# ...

# %%
x = 'Total_emissions'
size = 'calories [kcal]'
y = 'protein [g]'

# %%
fig = px.scatter(df, size= size, y=y,
                 x = x, color="Category",
           hover_name="Food product", size_max=60,
         color_discrete_sequence = davos_rgb
                )
fig.show()
# Out:
# <div>                            <div id="43bfc331-acb1-464d-8959-e36742e97ebb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43bfc331-acb1-464d-8959-e36742e97ebb")) {                    Plotly.newPlot(                        "43bfc331-acb1-464d-8959-e36742e97ebb",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Category=Grains<br>Total_emissions=%{x}<br>protein [g]=%{y}<br>calories [kcal]=%{marker.size}<extra></extra>","hovertext":["Wheat & Rye (Bread)","Rice"],"legendgroup":"Grains","marker":{"color":"rgb(44, 26, 76)","size":[263,358],"sizemode":"area","sizeref":0.18722222222222223,"symbol":"circle"},"mode":"markers","name":"Grains","orientation":"v","showlegend":true,"x":[1.4,4.0],"xaxis":"x","y":[0.01,6.5],"yaxis":"y","typ
# ...

# %%
# plt.figure(figsize=(8, 4))
# sns.scatterplot(df_food, x = x, y = y, size = size, hue = 'Category', palette=cm.davos.colors, legend='brief')
# plt.legend(loc=(1.04, 0))

# sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Anzahl pro Kategorie
#  - zur Übersicht ob etwas überrepräsentiert ist
#  - Aggregation, keine negative oder positive Aussage, keine Referenzwerte nötig
#   - Annotation/Farbe ja/nein

# %%
fig = px.sunburst(df, path=['NutritionalForm',  'Category', 'Allergens', 'Food product',], color='FurProc'
#                  ,color_discrete_sequence=px.colors.qualitative.Prism
                  , color_discrete_sequence = davos_rgb
#                                  , color_continuous_scale=davos[5]
                 )
fig.show()
# Out:
# <div>                            <div id="e1b68dc3-1d0b-42a9-a28a-273560856eaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1b68dc3-1d0b-42a9-a28a-273560856eaf")) {                    Plotly.newPlot(                        "e1b68dc3-1d0b-42a9-a28a-273560856eaf",                        [{"branchvalues":"total","customdata":[["no"],["no"],["no"],["yes"],["no"],["yes"],["yes"],["no"],["no"],["yes"],["yes"],["no"],["yes"],["no"],["no"],["no"],["yes"],["no"],["yes"],["yes"],["yes"],["yes"],["yes"],["yes"],["no"],["yes"],["no"],["yes"],["no"],["(?)"],["no"],["no"],["yes"],["yes"],["no"],["yes"],["no"],["yes"],["no"],["no"],["no"],["(?)"],["no"],["yes"],["yes"],["yes"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br
# ...

# %%
fig = px.histogram(df,
                 x = "Allergens", color="NutritionalForm",
                   color_discrete_sequence=davos_rgb[-7:],
                  )
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="2e035074-6041-4357-80f7-8d165a63e6d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e035074-6041-4357-80f7-8d165a63e6d3")) {                    Plotly.newPlot(                        "2e035074-6041-4357-80f7-8d165a63e6d3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"NutritionalForm=vegan<br>Allergens=%{x}<br>count=%{y}<extra></extra>","legendgroup":"vegan","marker":{"color":"rgb(96, 137, 190)","pattern":{"shape":""}},"name":"vegan","offsetgroup":"vegan","orientation":"v","showlegend":true,"x":["gluten","none","none","none","none","nuts","soya","soya","none","none","none","none","none"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x",
# ...

# %%
zhaw_color = (0.00000 , 0.39216 , 0.65098)

# %%
plt.figure(figsize=(8, 4))
sns.countplot(df_food, x= 'Allergens' , palette = sns.blend_palette(cm.davos.colors, n_colors=10), order=df['Allergens'].value_counts().index)
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(8, 4))
plots = sns.countplot(df_food, x= 'Allergens' , color= zhaw_color, order=df['Allergens'].value_counts().index)
sns.despine(left=True, bottom=True)

for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
fig = px.histogram(df,
                 x = "Category", color="FurProc",
                   color_discrete_sequence=davos_rgb)
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="e90bbc1d-c000-4c6b-a8bd-686a30bb86a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e90bbc1d-c000-4c6b-a8bd-686a30bb86a5")) {                    Plotly.newPlot(                        "e90bbc1d-c000-4c6b-a8bd-686a30bb86a5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"FurProc=yes<br>Category=%{x}<br>count=%{y}<extra></extra>","legendgroup":"yes","marker":{"color":"rgb(44, 26, 76)","pattern":{"shape":""}},"name":"yes","offsetgroup":"yes","orientation":"v","showlegend":true,"x":["Grains","Grains","Vegetables","Vegetables","Animal_Prod","Animal_Prod","Egg_Prod","Animal_Prod","Animal_Prod"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","
# ...

# %%
plt.figure(figsize=(10, 4))
# sns.histplot(df_food['Category'], hue = df_food['Further processing needed'], palette="rocket" )
sns.countplot(df_food, x='Category' , palette = cm.hawaii.colors, 
             order=df['Category'].value_counts().index)
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(10, 4))
# sns.histplot(df_food['Category'], hue = df_food['Further processing needed'], palette="rocket" )
plots = sns.countplot(df_food, x='Category' , palette = cm.hawaii.colors, 
                      order=df['Category'].value_counts().index)
sns.despine(left=True, bottom=True)

for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
plt.figure(figsize=(10, 4))

sns.countplot(df_food, x='NutritionalForm', palette = cm.davos.colors,
              order=df['NutritionalForm'].value_counts().index)

sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(10, 4))

plots = sns.countplot(df_food, x='NutritionalForm', palette = cm.hawaii.colors,
                      order=df['NutritionalForm'].value_counts().index)

sns.despine(left=True, bottom=True)


for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
plt.figure(figsize=(10, 4))
# sns.histplot(df_food['Category'], hue = df_food['Further processing needed'], palette="rocket" )
sns.countplot(df_food, x='FurProc' , palette = cm.hawaii.colors)
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(10, 4))
# sns.histplot(df_food['Category'], hue = df_food['Further processing needed'], palette="rocket" )
plots = sns.countplot(df_food, x='FurProc' , palette = cm.hawaii.colors)
sns.despine(left=True, bottom=True)

for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %% [markdown]
# ### Anzahl missing values
#  - Nur Anzahl pro Parameter oder Datensatz oder beides
#  - keine Referenzwerte
#  - fehlende Werte negativ notiert (dunkles rot/schwarz)
#      - Farben für Konsistenz beibehalten oder rot/schwarz?

# %%
df_food.set_index('Food product', inplace=True)

# %%
missing = df_food.isna().sum()[df_food.isna().sum() > 0]

# %%
missing_food =  df_food.isnull().sum(axis=1)[df_food.isna().sum(axis=1) > 0]

# %%
# !pip install missingno

import missingno as msno
msno.matrix(df_food, labels=True, color = zhaw_color, figsize=(40, 10),)
# Out:
# <AxesSubplot: >

# %%
msno.matrix(df_food, labels=True, color = [0.2784309759 ,0.0392161,0.1176469955], figsize=(40, 10),)
# Out:
# <AxesSubplot: >

# %%
fig = px.bar(y = missing.index , x = missing
           ,  color_discrete_sequence=davos_rgb
#                  ,color_continuous_scale=davos_rgb

            )
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="eceecd56-c115-4996-a082-02a77c071acc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eceecd56-c115-4996-a082-02a77c071acc")) {                    Plotly.newPlot(                        "eceecd56-c115-4996-a082-02a77c071acc",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(44, 26, 76)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[3,3,4,3,3,6],"xaxis":"x","y":["EuEmkg","Waterkg","GreGaskcal","Lndusekg","Scarkg","saturated_fat [g]"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour
# ...

# %%
plt.figure(figsize=(15, 8))
sns.barplot(y = missing.index , x = missing
           ,  order = missing.sort_values(ascending = False).index
          ,palette = cm.hawaii.colors
           )
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.title('Count of missing values',
          fontsize=18, color= 'black', fontweight='bold', )
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(15, 8))
sns.barplot(y = missing.index , x = missing, color = zhaw_color
           ,  order = missing.sort_values(ascending = False).index)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.title('Count of missing values',
          fontsize=18, color= 'black', fontweight='bold', )
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(15, 8))
sns.barplot(y = missing.index , x = missing, palette = sns.blend_palette(cm.davos.colors, n_colors=7)
           ,  order = missing.sort_values(ascending = False).index)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.title('Count of missing values',
          fontsize=18, color= 'black', fontweight='bold', )
sns.despine(left=True, bottom=True)

# %%
fig = px.bar(y = missing_food.index , x = missing_food
           ,  color_discrete_sequence=davos_rgb
#                  ,color_continuous_scale=davos_rgb

            )
fig.update_layout(yaxis={'categoryorder':'total ascending'})
fig.show()
# Out:
# <div>                            <div id="b2635b31-0b29-46d0-8688-eedd9b3a8733" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2635b31-0b29-46d0-8688-eedd9b3a8733")) {                    Plotly.newPlot(                        "b2635b31-0b29-46d0-8688-eedd9b3a8733",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(44, 26, 76)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[5,1,1,1,5,1,1,1,1,5],"xaxis":"x","y":["Wheat & Rye (Bread)","Potatoes","Beet Sugar","Soymilk","Tofu","Tomatoes","Onions & Leeks","Apples","Berries & Grapes","Shrimps (farmed)"],"yaxis":"y","type":"bar"}],                    
# ...

# %%
plt.figure(figsize=(15, 8))
sns.barplot(y = missing_food.index , x = missing_food
           ,  order = missing_food.sort_values(ascending = False).index
          ,palette = cm.davos.colors
           )
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.title('Count of missing values',
          fontsize=18, color= 'black', fontweight='bold', )
sns.despine(left=True, bottom=True)

# %%
# plt.figure(figsize=(20, 20))
# plots = sns.barplot(y = missing.index , x = missing, palette = cm.hawaii.colors
#                    ,  order = missing.sort_values(ascending = False).index)
# plt.yticks(fontsize=20)
# plt.xticks(fontsize=20)
# plt.title('Count of missing values',
#           fontsize=18, color= 'black', fontweight='bold', )
# sns.despine(left=True, bottom=True)

# annontations_hor(plots)

# %% [markdown]
# ### distribution of a certain parameter
#  - Verteilung der Daten, was sind typische hohe/niedrige Werte?
#  - Skala kann eine Rolle spielen, wenn kleine und große Wertebereiche bei den Parametern vorhanden sind (Kalorien vs Asche)
#  - trotzdem keine Referenzwerte verwendet, tatsächlicher Wertebereich soll abgebildet werden
#  - keine negative /Positive Bewertung der Verteilung

# %%
# column = ['calories [kcal]', 'EuEmkg', 'Total_emissions']
column = df_food.columns[23:27]

plt.figure(figsize=(17, 10))
sns.kdeplot(df_food[column], palette = sns.blend_palette(cm.davos.colors, n_colors=6))
# plt.yticks(fontsize=20)
# plt.xticks(fontsize=20)
sns.despine(left=True, bottom=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_18004\1584070248.py:5: UserWarning:
#
# The palette list has more values (6) than needed (4), which may not be intended.

# %%
# column = ['calories [kcal]', 'EuEmkg']

# plt.figure(figsize=(17, 10))
# sns.kdeplot(df_food[column], palette = cm.davos.colors)
# # plt.yticks(fontsize=20)
# # plt.xticks(fontsize=20)
# sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Bubbles with data
# Nur Anzahl der Datenquellen, Datensätze, Parameter

# %%
import numpy as np
import matplotlib.pyplot as plt

db_characterise = {
    'dimensions': ['food products: {}'.format(len(df_food.index)), 
                   'parameter : {}'.format(len(df_food.columns)), 'data sources: {}'.format(2)],
    'count': [len(df_food.index), len(df_food.columns), 2],
    'color': (sns.blend_palette(cm.davos.colors, n_colors=5)[-4:])
}


class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        """
        Setup for bubble collapse.

        Parameters
        ----------
        area : array-like
            Area of the bubbles.
        bubble_spacing : float, default: 0
            Minimal spacing between bubbles after collapsing.

        Notes
        -----
        If "area" is sorted, the results might look weird.
        """
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # calculate initial grid layout for bubbles
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        idx_min = np.argmin(distance)
        return idx_min if type(idx_min) == np.ndarray else [idx_min]

    def collapse(self, n_iterations=50):
        """
        Move bubbles to the center of mass.

        Parameters
        ----------
        n_iterations : int, default: 50
            Number of moves to perform.
        """
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                # try to move directly towards the center of mass
                # direction vector from bubble to the center of mass
                dir_vec = self.com - self.bubbles[i, :2]

                # shorten direction vector to have length of 1
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                # calculate new bubble position
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                # check whether new bubble collides with other bubbles
                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    # try to move around a bubble that you collide with
                    # find colliding bubble
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        # calculate direction vector
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        # calculate orthogonal vector
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        # test which direction to go
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        """
        Draw the bubble plot.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
        labels : list
            Labels of the bubbles.
        colors : list
            Colors of the bubbles.
        """
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center', 
                   color = 'black', fontsize = 18)


bubble_chart = BubbleChart(area=db_characterise['count'],
                           bubble_spacing=0.1)

bubble_chart.collapse()

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
bubble_chart.plot(
    ax, db_characterise['dimensions'], db_characterise['color'])
ax.axis("off")
ax.relim()
ax.autoscale_view()
ax.set_title('DB Characteristics')
ax.set_xticklabels(db_characterise['count'])

plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_18004\1354789195.py:159: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
