# %%
from cmcrameri import cm
import math as math
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

import plotly.express as px

# !pip install sparql_dataframe
import sparql_dataframe

# %% [markdown]
# ### TODO:
#  [ x ] wie units ausgeben
#
#  [  ] habe ich schon properties: allergene, ernährungsform
#
#  [  ] sehe ich missing values?
#
# [  ] mit variablen verschiedene Nährwerte auslesen
#
# [  ] diese zusammenrechenen - Beispiel Reis und Bohnen
#
# [  ] Studyresults bleiben bis jetzt

# %%
# funktioniert, kommt da alles?
#     ?recingredient schema:unitCode ?unit .
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT ?label ?value ?unit ?ingred ?material
WHERE {
	# ?dapro schema:ingredients ?foodoningredient .
  	# ?foodoningredient rdfs:label ?label .
 	# ?foodoningredient schema:ingredients ?ingred .


}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                                 label  value  unit  \
# 0   Vitamin B12-Cobalamin in Sardine roh Fischzusc...    NaN   NaN
# 1                           Sorbit in Hühnerei Eiweiß    NaN   NaN
# 2   Butansäure/Buttersäure in Bohnen dick Konserve...    NaN   NaN
# 3                    Eicosatriensäure in Geflügel roh    NaN   NaN
# 4       Vitamin B5-Pantothensäure in Walnuss gemahlen    NaN   NaN
# 5                  Vitamin B6-Pyridoxin in Grapefruit    NaN   NaN
# 6     Hexadecatetraensäure in Fischerzeugnisse gegart    NaN   NaN
# 7          Nichtessentielle Aminosäuren in Cashewnuss    NaN   NaN
# 8     Threonin in Kohlrabi Konserve, nicht abgetropft    NaN   NaN
# 9               Mittelkettige Fettsäuren in Rhabarber    NaN   NaN
# 10                             Threonin in Backerbsen    NaN   NaN
# 11                   Lactose (Milchzucker) in Mangold    NaN   NaN
# 12                          Poly-Hexosen in Mirabelle    NaN   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126098 entries, 0 to 126097
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   label     126098 non-null  object
#  1   value     0 non-null       float64
#  2   unit      0 non-null       float64
#  3   ingred    126098 non-null  object
#  4   material  0 non-null       float64
# dtypes: float64(3), object(2)
# memory usage: 4.8+ MB

# %%
# funktioniert, bei Ackerbohne kommen keine Nährwerte


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT ?foodoningredient ?foodoningredientval  ?name  ?recingredient ?nutri
WHERE {
	# ?dapro rdfs:label "Ackerbohne" .
	# ?dapro schema:ingredients ?recingredient .
	# ?recingredient schema:ingredients ?foodoningredient .
 	# ?foodoningredient rdfs:label ?name.
	# ?recingredient schema:value ?foodoningredientval . 


}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                  foodoningredient  foodoningredientval  \
# 0  http://purl.obolibrary.org/obo/FOODON_03301227                  1.0
#
#                  name                                      recingredient  \
# 0  broad bean (whole)  http://dapro.opendata.zhaw.ch/DaPro.owl#Ackerb...
#
#    nutri
# 0    NaN

# %%
# funktioniert, bei Ackerbohne kommen keine Nährwerte


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT ?foodoningredient ?foodoningredientval  ?name  ?recingredient ?nutri
WHERE {
	# ?dapro a schema:ingredient.
	# ?dapro schema:ingredients ?recingredient .
	# ?recingredient schema:ingredients ?foodoningredient .
 	# ?foodoningredient rdfs:label ?name.
	# ?recingredient schema:value ?foodoningredientval . 


}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
# Empty DataFrame
# Columns: [foodoningredient, foodoningredientval, name, recingredient, nutri]
# Index: []

# %%
# das funktioniert
    


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT *
WHERE {
 	# ?dapro rdfs:label "Birne" .
	# ?dapro schema:ingredients ?recingredient .
    # ?recingredient rdfs:label ?name.
	# ?recingredient schema:ingredients ?foodoningredient .
	# ?recingredient schema:value ?foodoningredientval .    

}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                               dapro  \
# 0   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 1   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 2   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 3   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 4   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 5   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 6   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 7   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 8   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 9   http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 10  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 11  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 12  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 13  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 14  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 15  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# 16  http://dapro.opendata.zhaw.ch/BLSDB.owl#F130000
# ...

# %%
# # das funktioniert
    

# endpoint = 'http://localhost:8000'

# q = """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
# SELECT ?foodoningredient ?foodoningredientval
# WHERE {
#  	?dapro rdfs:label ?foodoningredient .
#     ?dapro schema:ingredients ?recingredient1 .
#     ?recingredient1 schema:ingredients ?parameter .
#     ?recingredient1 schema:value ?parameterval .
#     ?recingredient1 schema:unitCode ?parameterunit .  
# 	?dapro schema:ingredients ?recingredient .
# 	?recingredient schema:ingredients ?foodoningredient .
# 	?recingredient schema:value ?foodoningredientval .  
#     ?recingredient schema:unitCode ?unit .
# }
#     """

# df = sparql_dataframe.get(endpoint, q)
# df.head(20)

# %%
    
    
# das funktioniert
    


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT ?foodoningredient ?foodoningredientval ?unit
WHERE {
    # ?dapro rdfs:label "Knoblauch" .
    # ?dapro schema:ingredients ?recingredient .
    # ?recingredient schema:ingredients ?foodoningredient .
    # ?recingredient schema:value ?foodoningredientval .
    # ?recingredient schema:unitCode ?unit .   
}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                         foodoningredient  foodoningredientval       unit
# 0                           Poly-Hexosen             0.380000    mg/100g
# 1                 Energie (Kilokalorien)             0.000000  kcal/100g
# 2                                 Leucin             0.019000    mg/100g
# 3                       Docosatriensäure             0.250000    mg/100g
# 4                        Pentadecensäure             0.923000    mg/100g
# 5    Oligosaccharide, sorbierbar (3-9 M)             0.000000    mg/100g
# 6            Vitamin A-Retinoläquivalent             0.000440    μg/100g
# 7                     Eicosapentaensäure             0.269000    mg/100g
# 8                   Glycerin und Lipoide             0.000000    mg/100g
# 9                                Arginin             0.149000    mg/100g
# 10                                Alanin             0.002700    mg/100g
# 11          Vitamin B7-Biotin (VitaminH)             0.000004    μg/100g
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT ?foodoningredient ?foodoningredientval ?name ?ingredient ?name1
WHERE {
	# ?dapro a dapro:Product .

	# ?dapro schema:ingredients ?recingredient .
	# ?recingredient schema:ingredients ?foodoningredient .
	# ?recingredient schema:value ?foodoningredientval .
	# ?CHFDMingredient rdfs:isDefinedBy ?foodoningredient .
    # ?recingredient rdfs:label ?name.
# ?foodoningredient rdfs:label ?name1.

}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                  foodoningredient  foodoningredientval  \
# 0  http://purl.obolibrary.org/obo/FOODON_00001634                1.000
# 1  http://purl.obolibrary.org/obo/FOODON_00002239                1.000
# 2  http://purl.obolibrary.org/obo/FOODON_03304292                0.010
# 3  http://purl.obolibrary.org/obo/FOODON_03310553                0.540
# 4  http://purl.obolibrary.org/obo/FOODON_03310809                0.170
# 5  http://purl.obolibrary.org/obo/FOODON_03544163                0.015
# 6  http://purl.obolibrary.org/obo/FOODON_03540171                0.015
# 7  http://purl.obolibrary.org/obo/FOODON_03305612                0.020
# 8  http://purl.obolibrary.org/obo/FOODON_03304292                0.004
# 9  http://purl.obolibrary.org/obo/FOODON_03301705                0.015
#
#                                              name  ingredient  \
# 0                         Anteil von 100 % Barsch         NaN
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT ?foodoningredient ?name ?foodoningredientval ?unit
WHERE {

    # ?dapro rdfs:label "Bio · Tofu · Curry".
   	# ?dapro schema:ingredients ?recingredient .
    # ?recingredient schema:ingredients ?foodoningredient .
    # ?recingredient schema:value ?foodoningredientval .
	# ?CHFDMingredient rdfs:isDefinedBy ?foodoningredient .
    # ?foodoningredient rdfs:label ?name.

}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                  foodoningredient                name  \
# 0  http://purl.obolibrary.org/obo/FOODON_03301415     soybean (whole)
# 1  http://purl.obolibrary.org/obo/FOODON_03301842        curry powder
# 2  http://purl.obolibrary.org/obo/FOODON_00002340  water food product
# 3  http://purl.obolibrary.org/obo/FOODON_03420108               sugar
# 4  http://purl.obolibrary.org/obo/FOODON_03307916       cider vinegar
#
#    foodoningredientval  unit
# 0                 0.40   NaN
# 1                 0.01   NaN
# 2                 0.50   NaN
# 3                 0.02   NaN
# 4                 0.01   NaN

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {

    # ?dapro rdfs:label "Bio · Tofu · Curry".
   	# ?dapro schema:ingredients ?recingredient .

    # ?recingredient schema:ingredients ?foodoningredient .
    # ?recingredient schema:value ?foodoningredientval .
	# ?CHFDMingredient rdfs:isDefinedBy ?foodoningredient .
    # ?CHFDMingredient rdfs:isDefinedBy ?otheringredients .
    # ?otheringredients  <http://schema.org/ingredients> ?material.
    # ?material schema:ingredients ?ingredientmat . 
    
    OPTIONAL{

    # ?material schema:value ?ingredientmatval .
    # ?material schema:unitCode ?ingredientmatunit .

    }
    BIND(?ingredientmatval * ?foodoningredientval AS ?poportioninproduct)


}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(30)
# Out:
#                                       CHFDMingredient  \
# 0   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 1   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 2   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 3   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 4   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 5   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 6   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 7   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 8   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 9   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 10  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 11  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 12  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 13  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 14  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 15  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
PREFIX obo: <http://purl.obolibrary.org/obo/>

SELECT *
WHERE {
    # ?CHFDMingredient rdfs:isDefinedBy  <http://purl.obolibrary.org/obo/FOODON_03301415> .
    # ?CHFDMingredient rdfs:isDefinedBy ?otheringredients.
    # ?CHFDMingredient schema:ingredients* ?ingredient . 
    <http://purl.obolibrary.org/obo/FOODON_03301415> rdfs:label ?name.
    OPTIONAL { 
    # ?otheringredients  <http://schema.org/ingredients> ?material.
    # ?material schema:ingredients ?ingredientmat . 
    }
}
"""

# 	?CHFDMingredient schema:ingredients ?ingredient .
#     ?dapro rdfs:label ?name.
#     ?dapro schema:unitCode ?unit .


df = sparql_dataframe.get(endpoint, q)
df.head(30)
# Out:
#                                       CHFDMingredient  \
# 0   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 1   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 2   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 3   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 4   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 5   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 6   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 7   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 8   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 9   http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 10  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 11  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 12  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 13  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 14  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# 15  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...
# ...

# %%
df.ingredientmat.unique()
# Out:
# array([nan, 'Alanin', 'Eicosansäure/Arachinsäure', 'Zucker (gesamt)',
#        'Lysin', 'Disaccharide (2M)', 'Purin', 'Phenylalanin',
#        'Hexadecensäure/Palmitoleinsäure', 'Vitamin B1-Thiamin',
#        'Mittelkettige Fettsäuren', 'Mannit',
#        'Nichtessentielle Aminosäuren', 'Tetracosensäure/Nervonsäure',
#        'http://purl.obolibrary.org/obo/FOODON_03420190',
#        'Maltose (Malzzucker)', 'Vitamin B5-Pantothensäure',
#        'Hexadecansäure/Palmitinsäure', 'Gesättigte Fettsäuren',
#        'Vitamin D-Calciferole', 'Mangan', 'Cystein', 'Xylit', 'Stärke',
#        'Vitamin C-Ascorbinsäure', 'Fructose (Fruchtzucker)',
#        'Vitamin B12-Cobalamin', 'Poly-Hexosen', 'Fluorid', 'Cholesterin',
#        'Iodid', 'Glykogen (tierische Stärke)', 'Octadecensäure/Ölsäure',
#        'Organische Säuren', 'Hexadecatetraensäure', 'Eicosensäure',
#        'Leucin', 'Lactose (Milchzucker)', 'Kalium',
#        'Octradecatetraensäure/Stearidonsäure', 'Glycerin und Lipoide',
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT ?foodoningredient ?name ?foodoningredientval
WHERE {

    # ?dapro rdfs:label 'Feta'.
   	# ?dapro schema:ingredients ?recingredient .
    # ?recingredient schema:ingredients ?foodoningredient .
    # ?recingredient schema:value ?foodoningredientval .
	# ?CHFDMingredient rdfs:isDefinedBy ?foodoningredient .
    # ?foodoningredient rdfs:label ?name.


}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                  foodoningredient                      name  \
# 0  http://purl.obolibrary.org/obo/FOODON_00004106  feta cheese food product
#
#    foodoningredientval
# 0                  1.0

# %%
# STOP


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	  # ?dapro a dapro:Product .
       # ?dapro schema:ingredients ?recingredient .
       # ?recingredient schema:ingredients ?foodoningredient .  
    # ?foodoningredient rdfs:label ?name1.
    }
"""


df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                                 dapro  \
# 0      http://dapro.opendata.zhaw.ch/DaPro.owl#Barsch
# 1    http://dapro.opendata.zhaw.ch/DaPro.owl#Crevette
# 2   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 3   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 4   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 5   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 6   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 7   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 8   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 9   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 10  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 11  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 12  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 13  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 14  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 15  http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# ...

# %%
df[400:]
# Out:
#                                                  dapro  \
# 400  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 401  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 402  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 403  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 404  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 405  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 406  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 407  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 408  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 409  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 410  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
#
#                                    foodoningredient  \
# 400  http://purl.obolibrary.org/obo/FOODON_00003405
# 401  http://purl.obolibrary.org/obo/FOODON_00001142
# 402  http://purl.obolibrary.org/obo/FOODON_03306851
# 403  http://purl.obolibrary.org/obo/FOODON_03304292
# ...

# %%
# geht, sagt mir nur, was drinnen ist

endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro a dapro:Brand.
    # ?dapro rdfs:label ?name.
}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                               dapro            name
# 0  http://dapro.opendata.zhaw.ch/DaPro.owl#B0000001  Garden Gourmet

# %%
# geht, sagt mir nur, was drinnen ist


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro a dapro:Producer.
    # ?dapro rdfs:label ?name.

}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                                dapro     name
# 0  http://dapro.opendata.zhaw.ch/DaPro.owl#PR0000001  Micarna

# %%
# geht, sagt mir nur, was drinnen ist - keine Suitable Diet, keine Prodcttype


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro a dapro:SuitableDiet.


}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
# Empty DataFrame
# Columns: [dapro]
# Index: []

# %%
# zu langsam, nur erste Zeiel müsste gehen ohne das:
#     ?foodoningredient rdfs:label ?name.


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro a dapro:Product.
    # ?dapro rdfs:label ?name.

}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                                                 dapro  \
# 0      http://dapro.opendata.zhaw.ch/DaPro.owl#Barsch
# 1    http://dapro.opendata.zhaw.ch/DaPro.owl#Crevette
# 2   http://dapro.opendata.zhaw.ch/DaPro.owl#Gemuse...
# 3        http://dapro.opendata.zhaw.ch/DaPro.owl#Feta
# 4     http://dapro.opendata.zhaw.ch/DaPro.owl#Forelle
# 5      http://dapro.opendata.zhaw.ch/DaPro.owl#Lupine
# 6   http://dapro.opendata.zhaw.ch/DaPro.owl#Pinien...
# 7    http://dapro.opendata.zhaw.ch/DaPro.owl#Seelachs
# 8   http://dapro.opendata.zhaw.ch/DaPro.owl#Kaninchen
# 9   http://dapro.opendata.zhaw.ch/DaPro.owl#Lammfl...
# 10  http://dapro.opendata.zhaw.ch/DaPro.owl#Chiasamen
# 11  http://dapro.opendata.zhaw.ch/DaPro.owl#Hanfsamen
# 12  http://dapro.opendata.zhaw.ch/DaPro.owl#V_Love...
# 13  http://dapro.opendata.zhaw.ch/DaPro.owl#Ackerb...
# 14      http://dapro.opendata.zhaw.ch/DaPro.owl#Sesam
# 15  http://dapro.opendata.zhaw.ch/DaPro.owl#Pferde...
# ...

# %%
# was ist hier der Unterschied????


endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro schema:ingredients ?ingredient .
        # ?dapro rdfs:label ?name.
            # ?dapro schema:unitCode ?unit .   
}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                                dapro  \
# 0  http://dapro.opendata.zhaw.ch/BLSDB.owl#H15040...
# 1  http://dapro.opendata.zhaw.ch/BLSDB.owl#M60200...
# 2  http://dapro.opendata.zhaw.ch/BLSDB.owl#Z117_6...
# 3  http://dapro.opendata.zhaw.ch/BLSDB.owl#H52000...
# 4  http://dapro.opendata.zhaw.ch/BLSDB.owl#D09000...
# 5  http://dapro.opendata.zhaw.ch/BLSDB.owl#H51090...
# 6  http://dapro.opendata.zhaw.ch/BLSDB.owl#G76010...
# 7  http://dapro.opendata.zhaw.ch/BLSDB.owl#C55900...
# 8  http://dapro.opendata.zhaw.ch/BLSDB.owl#R12300...
# 9  http://dapro.opendata.zhaw.ch/BLSDB.owl#Z120_6...
#
#                                    ingredient  \
# 0  http://purl.obolibrary.org/obo/CHEBI_16646
# 1  http://purl.obolibrary.org/obo/CHEBI_16646
# 2  http://purl.obolibrary.org/obo/CHEBI_16646
# 3  http://purl.obolibrary.org/obo/CHEBI_16646
# 4  http://purl.obolibrary.org/obo/CHEBI_16646
# 5  http://purl.obolibrary.org/obo/CHEBI_16646
# 6  http://purl.obolibrary.org/obo/CHEBI_16646
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

SELECT *
WHERE {
	# ?dapro a schema:ingredients .
    # ?dapro rdfs:label ?name. 

}
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                                dapro                name
# 0  http://dapro.opendata.zhaw.ch/CHNDB_one.owl#33...  Sojamehl, vollfett
# 1    http://dapro.opendata.zhaw.ch/BLSDB.owl#H011000    Sojaeiweißisolat

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT * WHERE {
	# ?CHFDMingredient rdfs:isDefinedBy <http://purl.obolibrary.org/obo/FOODON_03310553> .

}

"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                      CHFDMingredient
# 0  http://dapro.opendata.zhaw.ch/CHFoodDataMediat...

# %%
d = {}
food_items = ['Apfel',
 'Barsch',
 'Crevette',
 'Gemüsebällchen',
 'Feta',
 'Forelle',
 'Lupine',
 'Pinienkern',
 'Seelachs',
 'Kaninchen',
 'Lammfleisch',
 'Chiasamen',
 'Hanfsamen',
 'V-Love · Stick · Vegan',
 'Ackerbohne',
 'Sesam',
 'Pferdefleisch',
 'Kabeljau',
 'Bio · Tofu · Curry',
 'Bio Kale Burger',
 'V-Love · Falafel auf Basis von Kichererbsen · Vegan',
 'Pistazie',
 'Cashewnuss',
 'Hafer',
 'Lachs Wildfang',
 'Karpfen',
 'Macadamianuss',
 'Makrele',
 'Hartkäse',
 'Bio · Tofu · geräuchert',
 'Haselnuss',
 'Cornatur  Burger vegan',
 'Prix Garantie veganer Burger',
 'Linsen',
 'Mandel',
 "Anna's Best · Hummus · Nature",
 'Amaranth',
 'Gerste',
 'Reis',
 'M-Classic · Wienerli',
 'Limabohne',
 'Kalbfleisch',
 'Couscous',
 'The Green Mountain plant-based Burger',
 'Planted vegane filets mariniert',
 'Speck',
 'Lachs Zucht',
 'Wild',
 'Vegetarian Balls',
 'Hühnerei',
 'Erdnuss',
 'Kichererbse',
 'Leinsamen',
 'Mais',
 'Truthahn',
 'Sonnenblumenkern',
 'Edelkastanie',
 'Paranuss',
 'Yolo Crispy Burger',
 'Anchovis',
 'M-Classic · Cervelas',
 'Pekannuss',
 'Ziegenmilch',
 'Hartweizengriess',
 'Schweinefleisch',
 'Cornatur Quorn · Zitronenpfeffer Schnitzel',
 'Erbse',
 'Schafskäse',
 'Roggen',
 'Prix Garantie Falafelburger',
 'festivo geräucherter Stick VEGAN',
 'V-Love Burger vegan',
 'Kuhbohne/Augenbohne',
 'Pouletfleisch',
 'Bio Plant-Based Jäger',
 'Délicorn vegan Burger',
 'Adzukibohne',
 'Bio aha! · Tofu nature',
 'Dinkel',
 'Sojabohnen',
 'Tunfisch',
 'V-Love · Gehacktes · Vegan',
 'Walnuss',
 'Luzerne/Alfalfa',
 'Beyond Burger',
 'Kuhmilch',
 'Bio · Crispy Tofu · mit Sweet Chilisauce',
 'Gelberbse',
 'Rindfleisch',
 'Schafmilch',
 'Ente',
 'Migros V-Love · Kürbisburger · Vegan',
 'Hirse',
 'Ziegenkäse',
 'Tierprotein supplement ',
 'Garden Gourmet Sensational · Pfanzlicher Burger · aus Soja',
 'V-Love · Spinat-Falafel · Vegan',
 'Weizen',
 'Kürbiskern',
 'Weichkäse',
 'Délicorn vegan Nuggets',
 'Pintobohne',
 'Kidneybohne',
 'V-Love · Gemüse-Burger · Vegan']


endpoint = 'http://localhost:8000'
for item in food_items:
    q = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX schema: <http://schema.org/>
    PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

    SELECT   ?name1 ?UBP
    WHERE {{

        # ?ingredient rdfs:label "ecological scarcity 2013, total, UBP/kg in {}"   .
        # ?ingredient rdfs:label ?name1.
        # ?ingredient schema:value ?UBP .
        OPTIONAL{{ ?ingredient schema:unitCode ?unit .}}   
    }}
    """.format(item)


    df_interim = sparql_dataframe.get(endpoint, q)
    df_interim.set_index('name1', inplace = True)
    df_interim.rename(columns={"name1": item}, inplace = True)
    df_interim = df_interim.reindex(sorted(df_interim.index))
    d["df_{}".format(item)] = df_interim
    
df_dapro = d[next(iter(d))]
# # df_dapro.drop('unit', axis = 1, inplace = True)
for key in d.keys():
#     if d[key]['unit'].equals(d[next(iter(d))]['unit']):
        df_dapro = pd.concat([df_dapro, d[key][d[key].columns[0]]])
        
# df_dapro.drop('unit', axis = 1, inplace = True)
# df_dapro.set_index('unit', append = True, inplace = True)
# df_dapro.index = ['_'.join(ind) for ind in df_dapro.index.values]

# df_dapro=df_dapro.T

# %%
df_dapro
# Out:
#                                                        UBP         0
# name1
# ecological scarcity 2013, total, UBP/kg in Apfel    1344.7       NaN
# ecological scarcity 2013, total, UBP/kg in Apfel       NaN   1344.70
# ecological scarcity 2013, total, UBP/kg in Forelle     NaN  16778.00
# ecological scarcity 2013, total, UBP/kg in Lupine      NaN   8809.80
# ecological scarcity 2013, total, UBP/kg in Acke...     NaN   3705.60
# ecological scarcity 2013, total, UBP/kg in Sesam       NaN   5925.90
# ecological scarcity 2013, total, UBP/kg in Cash...     NaN  33222.00
# ecological scarcity 2013, total, UBP/kg in Hafer       NaN  10146.00
# ecological scarcity 2013, total, UBP/kg in Makrele     NaN   5773.50
# ecological scarcity 2013, total, UBP/kg in Hart...     NaN  35547.00
# ecological scarcity 2013, total, UBP/kg in Linsen      NaN   3922.50
# ecological scarcity 2013, total, UBP/kg in Mandel      NaN  12578.00
# ...

# %%
d = {}


endpoint = 'http://localhost:8000'
for item in food_items:
    q = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX schema: <http://schema.org/>
    PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>

    SELECT   *
    WHERE {{

        # ?ingredient rdfs:label "global warming potential (GWP100), IPCC 2013 in {}"   .
        # ?ingredient rdfs:label ?name1.
        OPTIONAL{{?ingredient schema:value ?UBP .}}
        OPTIONAL{{ ?ingredient schema:unitCode ?unit .}}  
    }}
    """.format(item)


    df_interim = sparql_dataframe.get(endpoint, q)
    df_interim.set_index('name1', inplace = True)
    df_interim.rename(columns={"name1": item}, inplace = True)
    df_interim = df_interim.reindex(sorted(df_interim.index))
    d["df_{}".format(item)] = df_interim
    
df_dapro = d[next(iter(d))]
# # df_dapro.drop('unit', axis = 1, inplace = True)
for key in d.keys():
#     if d[key]['unit'].equals(d[next(iter(d))]['unit']):
        df_dapro = pd.concat([df_dapro, d[key][d[key].columns[0]]])
        
# df_dapro.drop('unit', axis = 1, inplace = True)
# df_dapro.set_index('unit', append = True, inplace = True)
# df_dapro.index = ['_'.join(ind) for ind in df_dapro.index.values]

# df_dapro=df_dapro.T

# %%
df_dapro
# Out:
# Empty DataFrame
# Columns: [UBP, ingredient, unit, 0]
# Index: []

# %%
# das funktioniert
    

endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT ?foodoningredient ?foodoningredientval ?unit
WHERE {
 	# ?dapro rdfs:label "Gemüse" .
	# ?dapro schema:ingredients ?recingredient .
	# ?recingredient schema:ingredients ?foodoningredient .
	# ?recingredient schema:value ?foodoningredientval .  
    # ?recingredient schema:unitCode ?unit .
}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                        foodoningredient  foodoningredientval     unit
# 0             Vitamin B5-Pantothensäure         2.000000e-05  μg/100g
# 1                                 Purin         2.436000e+00  mg/100g
# 2        Wasserunlösliche Ballaststoffe         0.000000e+00  mg/100g
# 3                Langkettige Fettsäuren         0.000000e+00  mg/100g
# 4                  Hexadecatetraensäure         8.000000e-03  mg/100g
# 5                      Docosatriensäure         3.500000e-02  mg/100g
# 6               Glucose (Traubenzucker)         3.900000e-01  mg/100g
# 7               Vitamin C-Ascorbinsäure         2.000000e-05  μg/100g
# 8                Octadecensäure/Ölsäure         3.600000e-02  mg/100g
# 9           Vitamin A-Retinoläquivalent         8.000000e-04  μg/100g
# 10         Hexadecansäure/Palmitinsäure         8.000000e-02  mg/100g
# 11                              Tyrosin         1.100000e-02  mg/100g
# ...

# %%
# das funktioniert
    

endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT ?foodoningredient ?foodoningredientval ?unit
WHERE {
 	# ?dapro rdfs:label "Gemüse" .
	# ?dapro schema:ingredients ?recingredient .
	# ?recingredient schema:ingredients ?foodoningredient .
	# ?recingredient schema:value ?foodoningredientval .  
    # ?recingredient schema:unitCode ?unit .
}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
#                        foodoningredient  foodoningredientval     unit
# 0             Vitamin B5-Pantothensäure         2.000000e-05  μg/100g
# 1                                 Purin         2.436000e+00  mg/100g
# 2        Wasserunlösliche Ballaststoffe         0.000000e+00  mg/100g
# 3                Langkettige Fettsäuren         0.000000e+00  mg/100g
# 4                  Hexadecatetraensäure         8.000000e-03  mg/100g
# 5                      Docosatriensäure         3.500000e-02  mg/100g
# 6               Glucose (Traubenzucker)         3.900000e-01  mg/100g
# 7               Vitamin C-Ascorbinsäure         2.000000e-05  μg/100g
# 8                Octadecensäure/Ölsäure         3.600000e-02  mg/100g
# 9           Vitamin A-Retinoläquivalent         8.000000e-04  μg/100g
# 10         Hexadecansäure/Palmitinsäure         8.000000e-02  mg/100g
# 11                              Tyrosin         1.100000e-02  mg/100g
# ...

# %%
# # das funktioniert
    

# endpoint = 'http://localhost:8000'

# q = """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>


# SELECT *
# WHERE {
#     ?dapro rdfs:label "Bio · Tofu · Curry".
#     ?recingredient schema:ingredients ?foodoningredient .
#     ?recingredient schema:value ?foodoningredientval .
#     ?CHFDMingredient rdfs:isDefinedBy ?foodingredient.
#     ?CHFDMingredient rdfs:isDefinedBy ?otheringredients.
#     ?otheringredients  <http://schema.org/ingredients> ?material.
# }
#     """

# df = sparql_dataframe.get(endpoint, q, )
# df.head(20)

# %%
#     ?material rdftype ?<http://dapro.opendata.zhaw.ch/DaPro_one.owl#ContainsIngredientPercentage>.
#     ?material <http://schema.org/ingredients> ?istdasding.
#     ?material <http://schema.org/value> ?val1.
#     BIND((?foodoningredientval * ?val1) AS ?percentproteininproduct)

# %%
# # dauert zu lange
    

# endpoint = 'http://localhost:8000'

# q = """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
# SELECT *
# WHERE {
#  	?dapro rdfs:label "Gemüse" .
# 	?dapro schema:ingredients ?foodoningredient .
#  	?recingredient schema:value ?foodoningredientval .  

# }
#     """

# df = sparql_dataframe.get(endpoint, q)
# df.head(20)

# %%
# 	?dapro schema:ingredients ?recingredient .
#  	?recingredient schema:value ?foodoningredientval .  
#     ?recingredient schema:unitCode ?unit .

# %%
# endpoint = 'http://localhost:8000'

# q = """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
# PREFIX foodon: <http://purl.obolibrary.org/obo/foodon.owl#>

# SELECT *
# WHERE {
# 	?foodon a foodon:food product


# }
# """


# df = sparql_dataframe.get(endpoint, q)
# df.head(10)

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX foodon: <http://purl.obolibrary.org/obo/FOODON_﻿>
SELECT
	# ?search	
	(STR(?label) AS ?name) 
	(count(?class) as ?total) 
	WHERE {
	values ?search {
		foodon:03411041 # Chemical food component
		obo:OBI_0100026 # Organism (NCBI taxonomy)
		foodon:03411564 # Food product organismal source
		foodon:03420116 # Part of organism (anatomy)
		foodon:00002381 # Food product by organism (~single component food)
		foodon:00002501 # Multi-component food product
		foodon:00002451 # Food transformation process
		foodon:00003368 # Food contact material
		foodon:03400361 # Agency food product type
	}
	{?class rdfs:subClassOf+ ?search}
	OPTIONAL {?search rdfs:label ?label.}
} 
GROUP BY ?search ?label
"""


df = sparql_dataframe.get(endpoint, q)
df.head(10)
# Out:
#                                        search      name  total
# 0  http://purl.obolibrary.org/obo/OBI_0100026  organism   7240

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>


SELECT DISTINCT ?class ?label

WHERE {
    BIND( obo:FOODON_00001002 as ?search).
  

    {?class rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf ?search. }
    OPTIONAL {?class rdfs:label ?label. }
}
"""
df = sparql_dataframe.get(endpoint, q)
df.head(30)
# Out:
#                                              class  \
# 0   http://purl.obolibrary.org/obo/FOODON_00002832
# 1   http://purl.obolibrary.org/obo/FOODON_03317626
# 2   http://purl.obolibrary.org/obo/FOODON_03316480
# 3   http://purl.obolibrary.org/obo/FOODON_03301363
# 4   http://purl.obolibrary.org/obo/FOODON_00003139
# 5   http://purl.obolibrary.org/obo/FOODON_00001847
# 6   http://purl.obolibrary.org/obo/FOODON_03311168
# 7   http://purl.obolibrary.org/obo/FOODON_00003793
# 8   http://purl.obolibrary.org/obo/FOODON_03000130
# 9   http://purl.obolibrary.org/obo/FOODON_03316348
# 10  http://purl.obolibrary.org/obo/FOODON_03301223
# 11  http://purl.obolibrary.org/obo/FOODON_03303834
# 12  http://purl.obolibrary.org/obo/FOODON_03305514
# 13  http://purl.obolibrary.org/obo/FOODON_03306144
# 14  http://purl.obolibrary.org/obo/FOODON_03305436
# 15  http://purl.obolibrary.org/obo/FOODON_03306237
# 16  http://purl.obolibrary.org/obo/FOODON_03305481
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>


SELECT DISTINCT ?class  ?name ?ingredientmat ?label ?material ?otheringredients

WHERE {
    BIND( obo:FOODON_00001002 as ?search).
  

    {?class rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf ?search. }
    OPTIONAL {?class rdfs:label ?label. }
    # ?CHFDMingredient rdfs:isDefinedBy  ?class .
    # ?CHFDMingredient rdfs:isDefinedBy ?otheringredients.
    # ?otheringredients  <http://schema.org/ingredients> ?material.
    # ?material schema:ingredients ?ingredientmat .
    OPTIONAL {?otheringredients  <http://schema.org/suitableForDiet> ?diet.}

}
"""
df = sparql_dataframe.get(endpoint, q)
df.head(30)
# Out:
#                                              class  name  \
# 0   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 1   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 2   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 3   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 4   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 5   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 6   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 7   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 8   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 9   http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 10  http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 11  http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 12  http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 13  http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# 14  http://purl.obolibrary.org/obo/FOODON_03301223   NaN
# ...

# %%
endpoint = 'http://localhost:8000'

q = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX schema: <http://schema.org/>
PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
SELECT *
WHERE {
 	# ?dapro rdfs:subClassOf <http://purl.obolibrary.org/obo/FOODON_00001786>.
    # ?dapro rdfs:label ?label. 
    # ?dapro schema:ingredients ?nutrition.

}
    """

df = sparql_dataframe.get(endpoint, q)
df.head(20)
# Out:
# Empty DataFrame
# Columns: [dapro, label, nutrition]
# Index: []

# %%
#     endpoint = 'http://localhost:8000'

# q = """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX dapro: <http://dapro.opendata.zhaw.ch/DaPro.owl#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>


# SELECT DISTINCT ?class ?label

# WHERE {
#     BIND( obo:FOODON_00001002 as ?search).
  

#     {?class rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf/rdfs:subClassOf ?search. }
#     OPTIONAL {?class rdfs:label ?label. }
#     ?class schema:ingredients ?foodoningredient .
#     ?recingredient schema:value ?foodoningredientval .
#     ?recingredient schema:unitCode ?unit 
# }
# """
# df = sparql_dataframe.get(endpoint, q)
# df.head(30)
